# %%
import pandas as pd
import numpy as np
import re
from IPython.core.display import display, HTML, Markdown
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.insert(1, '../scripts/')

import eda_tools as et
import data_munging_tools as dmt
# import impute_eval as ie
# import model_fitting_tools as mft

# %% [markdown]
# ## Load data dict

# %%
# `read_html()`  requires packages: lxml, html5lib, beautifulsoup4
data_dict = (pd.read_html('../data/AttributeDescriptions.html')[0]
             .copy()
             .rename(columns=lambda x: x.lower().replace(" ", "_"))
             .assign(field_name=lambda x: x["field_name"].apply(lambda x: x.lower()))
             .set_index("field_name")
             .sort_index()
            )

# %%
data_dict.style.set_properties(subset=['description'], **{'width': '700px'})
# Out:
# <style  type="text/css" >
#     #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row0_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row1_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row2_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row3_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row4_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row5_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row6_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row7_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row8_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row9_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row10_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row11_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row12_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row13_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row14_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row15_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row16_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row17_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row18_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row19_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row20_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row21_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row22_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row23_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row24_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row25_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row26_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row27_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row28_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row29_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row30_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row31_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row32_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row33_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row34_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row35_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row36_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row37_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row38_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row39_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row40_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row41_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row42_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row43_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row44_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row45_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row46_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row47_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row48_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row49_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row50_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row51_col1 {
#             width:  700px;
#         }    #T_4e8b1d52_adb9_11e9_9406_705681b45dc1row52_col1 {
#             width:  700px;
#         }</style><table id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >category</th>        <th class="col_heading level0 col1" >description</th>    </tr>    <tr>        <th class="index_name level0" >field_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row0" class="row_heading level0 row0" >api</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row0_col0" class="data row0 col0" >Identifier</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row0_col1" class="data row0 col1" >Globally unique identifier for the well</td>
#             </tr>
#             <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row1" class="row_heading level0 row1" >bakken_isopach_ft</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row1_col0" class="data row1 col0" >Geology</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row1_col1" class="data row1 col1" >Thickness of the oil producing Bakken formation at the latitude/longitude of the well</td>
#             </tr>
#             <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row2" class="row_heading level0 row2" >bh_lat</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row2_col0" class="data row2 col0" >Location</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row2_col1" class="data row2 col1" >Latitude of the 'bottom hole' (the end of the laterally drilled bore)</td>
#             </tr>
#             <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row3" class="row_heading level0 row3" >bh_lng</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row3_col0" class="data row3 col0" >Location</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row3_col1" class="data row3 col1" >Longitude of the 'bottom hole' (the end of the laterally drilled bore)</td>
#             </tr>
#             <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row4" class="row_heading level0 row4" >choke_size</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row4_col0" class="data row4 col0" >nan</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row4_col1" class="data row4 col1" >Diameter in inches of the mechanical flow limiter</td>
#             </tr>
#             <tr>
#                         <th id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1level0_row5" class="row_heading level0 row5" >countyname</th>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row5_col0" class="data row5 col0" >Location</td>
#                         <td id="T_4e8b1d52_adb9_11e9_9406_705681b45dc1row5_col1" class="data row5 col1" >Name of the County where the well is located</td>

# %%
# Load the dataframes
test_df = pd.read_csv('../data/cleaned-input.test.tsv', sep='\t', low_memory=False)
train_df = pd.read_csv('../data/cleaned-input.training.tsv', sep='\t', low_memory=False)

# %%
inspect_df = (train_df.copy()
                      .rename(columns=str.lower)
                      .assign(api = lambda x: x["api"].str.strip("US"))
                      .set_index("api")
                      .sort_index(axis=1)
                      .assign(length=lambda x: dmt.haversine_distance(x["surface_lat"], x["surface_lng"], x["bh_lat"], x["bh_lng"]))
             )

# %% [markdown]
# # Categorical Columns

# %%
cat_df = inspect_df.copy().select_dtypes("O")

# %%
for col in cat_df.columns:
    nunique = cat_df[col].nunique()
    
    if nunique <= 20:
        display(Markdown(f"### {col}: {nunique}"))
        display(cat_df[col].value_counts().to_frame())
    else:
        display(Markdown(f"### {col}: **{nunique}**"))
# Out:
# ### choke_size: **217**
# ### countyname: 15
#                countyname
# MCKENZIE             1796
# MOUNTRAIL            1605
# WILLIAMS             1081
# DUNN                 1078
# DIVIDE                432
# BURKE                 182
# STARK                 133
# BILLINGS              101
# BOTTINEAU              81
# MCLEAN                 25
# GOLDEN VALLEY           8
# RENVILLE                3
# SLOPE                   2
# WARD                    1
# MERCER                  1
# ### currentoperator: **56**
# ### currentwellname: **6529**
# ### fieldname: **333**
# ### footages: **6120**
# ### leasename: **3231**
# ### leasenumber: **4523**
# ### originaloperator: **99**
# ### originalwellname: **6527**
# ### producedpools: 13
#                      producedpools
# BAKKEN                        6310
# SANISH                          82
# SPEARFISH                       72
# BAKKEN/THREE FORKS              30
# SPEARFISH/MADISON                8
# MADISON                          6
# TYLER                            2
# THREE FORKS                      2
# LODGEPOLE                        2
# RED RIVER                        1
# BAKKEN,WINNIPEGOSIS              1
# BIRDBEAR                         1
# MADISON,TYLER                    1
# ### qq: **43**
# ### range: **24**
# ### spud_date: **2133**
# ### stimulated_formation: 14
#                     stimulated_formation
# bakken                              3987
# three forks                         1617
# spearfish                             85
# pronghorn                              7
# madison                                4
# tyler                                  3
# bakken,three forks                     2
# red river                              2
# scallion                               1
# bluell                                 1
# bakken,pronghorn                       1
# lodgepole                              1
# bakken/three forks                     1
# nesson                                 1
# ### township: **30**
# ### type_treatment: 9
#                              type_treatment
# sand frac                              4618
# other                                   622
# fracture                                158
# other,sand frac                           3
# acid                                      2
# hydrochloric acid                         1
# hydrochloric acid,sand frac               1
# acid,gelled acid                          1
# fracture,sand frac                        1
# ### well_status_date: **2151**
# ### wellbore: 3
#                      wellbore
# HORIZONTAL               6519
# HORIZONTAL RE-ENTRY         6
# DIRECTIONAL                 4
# ### wellstatus: 8
#      wellstatus
# A          6248
# IA          250
# DRL           7
# TA            7
# PA            7
# AB            5
# DRY           3
# PNC           2
# ### welltype: 1
#     welltype
# OG      6529

# %% [markdown]
# # Space and time

# %%
inspect_df.length.plot.hist(bins=30)

# %%
inspect_df.query("length < 2000").shape[0]
# Out:
# 316

# %% [markdown]
# # Choke Size

# %% [markdown]
# https://gohaynesvilleshale.com/group/sanaugustine/forum/topics/what-is-the-choke-and-how-does-it-effect-production-rates

# %%
def parse_choke_size(x):
    replace_dict = {"a": "6", "s": "5", "i": "1", "0pen": "1", "b": "6", "g": "9"}
    
    if x == "na":
        return 1
    
    if type(x) == float and np.isnan(x):
        return x
    
    if type(x) != str:
        print(x, type(x))
        return np.nan
    
    if "/" not in x:
        return np.nan
    
    for k, v in replace_dict.items():
        x = x.replace(k, v)
        
    x = x.strip("'").strip("_").strip(" ").strip("'")
    
    fraction = x.split("/")
    if len(fraction) != 2:
        return np.nan
    num, denom = fraction[0], fraction[1]
    
    
    try:
        num = int(num)
        denom = int(denom)
        
    except:
#         print(f"couldnt_convert {num} / {denom}")
        return np.nan
    
    
    if num == denom:
        # 64/64 would be open ratio, but assume it is open
        return 1
    
    elif num > denom:
        # 64/64 would be open ratio, but assume it is open
        return np.nan
    
    else:
        decimal = num / denom
        return decimal

# %%
inspect_df["choke_size_new"] = inspect_df.choke_size.apply(lambda x: parse_choke_size(x))

# %%
inspect_df.choke_size_new.isnull().sum() / inspect_df.shape[0]
# Out:
# 0.20401286567621382

# %%
inspect_df.choke_size_new.plot.hist(bins=30)

# %%
result = test_df.choke_size.apply(lambda x: parse_choke_size(x))

# %%
result.plot.hist(bins=30)

# %% [markdown]
# ### Plots

# %%
cat_df = (inspect_df.copy()
                  .select_dtypes("O")
                  .pipe(dmt.drop_hi_lo_card)
                  .drop(["choke_size"], axis=1)
                  .pipe(dmt.reduce_cardinality)
         )
# Out:
# Shape before cardinality removal: (6529, 21)
# Shape after cardinality removal: (6529, 13)

# %%
cat_cols = cat_df.columns

# %%
cat_df = cat_df.join(inspect_df.filter(["production_liquid_180"]))

# %%
cat_df.head()
# Out:
#                countyname                  currentoperator fieldname  \
# api
# 33105034550000   WILLIAMS  WHITING OIL AND GAS CORPORATION     OTHER
# 33053034020000   MCKENZIE  HESS BAKKEN INVESTMENTS II, LLC     OTHER
# 33061026020000  MOUNTRAIL                            OTHER     OTHER
# 33089007540000      OTHER  WHITING OIL AND GAS CORPORATION     OTHER
# 33061021060000  MOUNTRAIL                            OTHER     OTHER
#
#                                originaloperator producedpools     qq  range  \
# api
# 33105034550000                            OTHER        BAKKEN   SESE  OTHER
# 33053034020000                            OTHER        BAKKEN  OTHER  OTHER
# 33061026020000                            OTHER        BAKKEN   NENW  OTHER
# 33089007540000  WHITING OIL AND GAS CORPORATION        BAKKEN   NENW  OTHER
# 33061021060000                            OTHER        BAKKEN  OTHER  OTHER
#
#                stimulated_formation township type_treatment    wellbore  \
# api
# 33105034550000               bakken    154 N      sand frac  HORIZONTAL
# 33053034020000               bakken    151 N      sand frac  HORIZONTAL
# 33061026020000          three forks    155 N       fracture  HORIZONTAL
# 33089007540000               bakken    OTHER      sand frac  HORIZONTAL
# 33061021060000               bakken    155 N            NaN  HORIZONTAL
#
#                wellstatus  production_liquid_180
# api
# 33105034550000          A                48302.0
# 33053034020000          A                58729.0
# 33061026020000          A                17221.0
# 33089007540000          A                44904.0
# 33061021060000          A               104497.0

# %%
def bar_plots(df, cat_cols, target_col):
    """
    Pass a dataframe, a list of columns that are categorical features, and a
    continuous target variable.

    Returns a two barcharts for each categorical feature:
     1. a count of the number of unique values in that column
     2. the median score of the target column fo each unique value in that column.
     """

    plt.rcParams.update({'font.size': 14})
    
    for col in cat_cols:
        fig, ax = plt.subplots(1, 2, figsize=(16, 5))
        vc = df[col].value_counts().sort_index()
        gb = df.groupby(col).median()[target_col].sort_index()
        
        ax[0].bar(range(vc.size),vc)
        ax[0].set_xticks(range(vc.size))
        ax[0].set_xticklabels(vc.index, fontsize=9, rotation=90)
        ax[0].set_title("Value counts of {}".format(col))
        
        ax[1].bar(range(gb.size),gb)
        ax[1].set_xticks(range(gb.size))
        ax[1].set_xticklabels(gb.index, fontsize=9, rotation=90)
        ax[1].set_title("Median {} by {}".format(target_col, col))


    plt.tight_layout()
    plt.show()

# %%
bar_plots(cat_df, cat_cols=cat_cols, target_col="production_liquid_180")
